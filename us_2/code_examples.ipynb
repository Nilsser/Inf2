# %% [markdown]
# ### Code Beispiele ÜS2
# Diese Datei dient nur zu Demonstrationszwecken während der Lektion, ihr **müsst die Datei nicht herunterladen** / clonen.

# %% [markdown]
# **input**

# %%
ip=input('gib eine Zahl ein: ') 
print('du hast die Zahl', ip, 'eingegeben')
# Out:
# du hast die Zahl  eingegeben

# %% [markdown]
# **Docstrings**
# Bemerkung: um docstrings sehen zu können muss es in einem geeigneten Editor geöffnet werden, CodeExpert unterstützt dies ebenfalls nicht.

# %%
#hello world funktion mit docstring
def hello_world():
    """
    Diese Funktion gibt "Hello, World!" aus.
    """
    print("Hello, World!")
    
#Aufruf der Funktion
hello_world()
# Out:
# Hello, World!

# %% [markdown]
# **In python ist alles ein Pointer:** kopieren einer Liste

# %%
fruits = ['apple', 'banana', 'cherry', 'orange']

x = fruits.copy()
fruits.append('grape')
print('x bleibt unverändert:', x,)
print('\nfruits enthält jetzt grape:', fruits)

#alternative: (slicing)
sliced_copy = fruits[:]
print('sliced_copy bleibt unverändert:', sliced_copy)
# Out:
# x bleibt unverändert: ['apple', 'banana', 'cherry', 'orange']
#
# fruits enthält jetzt grape: ['apple', 'banana', 'cherry', 'orange', 'grape']
# sliced_copy bleibt unverändert: ['apple', 'banana', 'cherry', 'orange', 'grape']

# %% [markdown]
# **Listen "Wie ein Ring behandeln"**

# %%
l= [1, 2, 3, 4, 5]
#nutze den modulo operator um von einem index n aus über die liste zu iterieren
n = 2
for i in range(n, n + len(l)):

    print(l[i % len(l)])
# Out:
# 3
# 4
# 5
# 1
# 2

# %%
l[0:len(l):1]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **Dictionary essentials**, für Crops&Dictionaries aufgabe

# %%
# beispiel dictionary:
person = {'name': 'Alice', 'age': 30, 'city': 'New York'} #es gilt key:value

#iterieren über dictionary:
for key in person:
    print(key, ':', person[key])

#oder:
for key, value in person.items():
    print(key, ':', value,)

#erstellen eines neuen dictionarys (ohne comprehension):
squared_numbers = {}
for key in range(1, 6): #key ist hier die Zahl von 1 bis 5, welche wir quadrieren wollen.
    squared_numbers[key] = key ** 2
print(squared_numbers)
# Out:
# name : Alice
# age : 30
# city : New York
# name : Alice
# age : 30
# city : New York
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# **Exceptions**

# %%
try:
    eingabe = input("Bitte gib dein Alter ein: ")
    alter = int(eingabe)  # Hier passiert der Fehler, wenn es keine Zahl ist
    print(f"Cool, du bist ungefähr {alter*365} Tage alt.")
    

except ValueError:
    # Dieser Block wird nur ausgeführt, wenn int() scheitert
    print("Fehler: Das war keine Zahl! Bitte benutze nur Ziffern (0-9).")

finally:
    print("Danke für die Eingabe!")
# Out:
# Fehler: Das war keine Zahl! Bitte benutze nur Ziffern (0-9).
# Danke für die Eingabe!

# %%
#use zip and dict to create a dictionary from two lists:
keys = ['name', 'age', 'city', 'country']
values = ['Alice', 30, 'New York', 'USA']
my_dict = dict(zip(keys, values))
my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
my_dict['name'] = 'Bob' #überschreibt den Wert von 'name' mit 'Bob'
print(my_dict)

print(my_dict['name']) #gib den Wert des keys 'name' aus
# Out:
# {'name': 'Bob', 'age': 30, 'city': 'New York'}
# Bob

# %%
l = [1, 2, 3, 4, 5]
print(l[::-1])
# Out:
# [5, 4, 3, 2, 1]
